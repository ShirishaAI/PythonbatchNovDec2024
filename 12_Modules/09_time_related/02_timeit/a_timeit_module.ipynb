# %% [markdown]
# time magicblock

# %%
2**128
# Out:
# 340282366920938463463374607431768211456

# %%
# %time 2**128
# Out:
# CPU times: user 5 μs, sys: 0 ns, total: 5 μs
# Wall time: 7.39 μs
# 340282366920938463463374607431768211456

# %%
n = 10000000
# %time sum(range(n))
# Out:
# CPU times: user 159 ms, sys: 0 ns, total: 159 ms
# Wall time: 158 ms
# 49999995000000

# %%
# %time print('hello world')
# Out:
# hello world
# CPU times: user 59 μs, sys: 0 ns, total: 59 μs
# Wall time: 53.6 μs

# %%
# %time 3**999
# Out:
# CPU times: user 5 μs, sys: 0 ns, total: 5 μs
# Wall time: 8.58 μs
# ...

# %% [markdown]
# timeit magicblock

# %%
# %timeit pass
# Out:
# 6.52 ns ± 0.55 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %%
# %time 3**99
# Out:
# CPU times: user 4 μs, sys: 0 ns, total: 4 μs
# Wall time: 6.2 μs
# 171792506910670443678820376588540424234035840667

# %%
u = None
# %timeit u is None
# Out:
# 13.3 ns ± 0.761 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %%
# %timeit -r 4 u == None
# Out:
# 18.1 ns ± 0.994 ns per loop (mean ± std. dev. of 4 runs, 100,000,000 loops each)

# %%
import time

# %timeit -n 1 time.sleep(2)
# Out:
# 2 s ± 8.38 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit sum(range(100))
# Out:
# 740 ns ± 45.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# 147 ms ± 25.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import random

L = [random.random() for i in range(100000)]
# %timeit L.sort()
# Out:
# 417 μs ± 33.7 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%time
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# CPU times: user 210 ms, sys: 0 ns, total: 210 ms
# Wall time: 214 ms

# %% [markdown]
# further reference: https://jakevdp.github.io/PythonDataScienceHandbook/01.07-timing-and-profiling.html

# %% [markdown]
# Example - String Concatenation
#
#  string concatenation using + operator
#
#  "".join()
#
#  old style format
#
#  new style format
#
#  f-strings
#
#  string.Template

# %%
s = "Tom"
t = "Brady"

# %timeit f'{s} {t}'
# Out:
# 62.9 ns ± 5.29 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit s + ' ' + t
# Out:
# 83 ns ± 7.39 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit ' '.join((s,t))
# Out:
# 90.1 ns ± 11.2 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit '%s %s'%(s,t)
# Out:
# 93.5 ns ± 7.8 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit '{} {}'.format(s,t)
# Out:
# 183 ns ± 11.2 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
from string import Template

# %%
# %timeit Template('$s $t').substitute(s=s, t=t)
# Out:
# 1.86 μs ± 155 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
import timeit

# %%
timeit.timeit("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]")
# Out:
# 0.5031222870002239

# %%
timeit.timeit("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]", number=1000)
# Out:
# 0.00046925399874453433

# %%
timeit.repeat("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]")
# Out:
# [0.5634980469985749,
#  0.5499050140006148,
#  0.4773531249993539,
#  0.49522632299886027,
#  0.46189258100093866]

# %%
min(timeit.repeat("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]"))
# Out:
# 0.4701064890014095

# %%
import cProfile

cProfile.run("[(a, b) for a in (1, 3, 5) for b in (2, 4, 6)]")
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
