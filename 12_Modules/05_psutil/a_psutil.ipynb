# %% [markdown]
# #### Psutil
#
# process level details

# %%
import psutil
import datetime

# %%
boot_time = psutil.boot_time()
print(
    f"System boot time: {datetime.datetime.fromtimestamp(boot_time).strftime('%Y-%m-%d %H:%M:%S')}"
)
# Out:
# System boot time: 2025-01-07 03:20:06

# %%
cpu_percent = psutil.cpu_percent()
print(f"CPU usage: {cpu_percent}%")
# Out:
# CPU usage: 7.3%

# %%
mem_info = psutil.virtual_memory()
print(f"Total memory       : {mem_info.total}")
print(f"Available memory   : {mem_info.available}")
print(f"Memory percent used: {mem_info.percent}%")
# Out:
# Total memory       : 8314740736
# Available memory   : 4620140544
# Memory percent used: 44.4%

# %%
disk_usage = psutil.disk_usage("/")
print(f"Total disk space       : {disk_usage.total}")
print(f"Free disk space        : {disk_usage.free}")
print(f"Disk space percent used: {disk_usage.percent}%")
# Out:
# Total disk space       : 33636024320
# Free disk space        : 20606550016
# Disk space percent used: 35.4%

# %%
num_processes = len(psutil.pids())
print(f"Number of processes: {num_processes}")
# Out:
# Number of processes: 27

# %%
pids_5 = list(psutil.pids())[-5:]

for pid in pids_5:
    process = psutil.Process(pid)
    print(f"Process name       : {process.name()}")
    print(f"Process status     : {process.status()}")
    print(f"Process memory info: {process.memory_info()}")

    cpu_percent = process.cpu_percent(interval=1)
    print(f"Process CPU usage: {cpu_percent}%")

    memory_info = process.memory_info()
    print(f"Process memory usage: {memory_info.rss}")

    start_time = process.create_time()
    print(f"Process start time: {start_time}")

    cmdline = process.cmdline()
    print(f"Process command line: {cmdline}")
    print()
# Out:
# Process name       : sh
# Process status     : sleeping
# Process memory info: pmem(rss=1572864, vms=2678784, shared=1572864, text=77824, lib=0, data=323584, dirty=0)
# Process CPU usage: 0.0%
# Process memory usage: 1572864
# Process start time: 1736227761.04
# Process command line: ['/bin/sh']
#
# Process name       : sh
# Process status     : sleeping
# Process memory info: pmem(rss=1572864, vms=2678784, shared=1572864, text=77824, lib=0, data=323584, dirty=0)
# Process CPU usage: 0.0%
# Process memory usage: 1572864
# Process start time: 1736227761.2
# Process command line: ['/bin/sh']
#
# Process name       : node
# Process status     : sleeping
# Process memory info: pmem(rss=54181888, vms=1018294272, shared=41943040, text=29884416, lib=0, data=56016896, dirty=0)
# Process CPU usage: 0.0%
# Process memory usage: 54181888
# Process start time: 1736228857.54
# Process command line: ['/vscode/bin/linux-x64/fabdb6a30b49f79a7aba0f2ad9df9b399473380f/node', '/vscode/bin/linux-x64/fabdb6a30b49f79a7aba0f2ad9df9b399473380f/extensions/markdown-language-features/dist/serverWorkerMain', '--node-ipc', '--clientProcessId=51549']
#
# Process name       : node
# Process status     : sleeping
# Process memory info: pmem(rss=58245120, vms=1018339328, shared=41811968, text=29884416, lib=0, data=58941440, dirty=0)
# Process CPU usage: 0.0%
# Process memory usage: 58245120
# Process start time: 1736229314.91
# Process command line: ['/vscode/bin/linux-x64/fabdb6a30b49f79a7aba0f2ad9df9b399473380f/node', '/vscode/bin/linux-x64/fabdb6a30b49f79a7aba0f2ad9df9b399473380f/extensions/json-language-features/server/dist/node/jsonServerMain', '--node-ipc', '--clientProcessId=51549']
#
# Process name       : python3
# Process status     : running
# Process memory info: pmem(rss=68542464, vms=699281408, shared=16908288, text=2752512, lib=0, data=135933952, dirty=0)
# Process CPU usage: 0.0%
# Process memory usage: 68542464
# Process start time: 1736229359.28
# Process command line: ['/home/codespace/.python/current/bin/python3', '-m', 'ipykernel_launcher', '--f=/home/codespace/.local/share/jupyter/runtime/kernel-v38db9ef089ad79fdbbb3887c1f0c533edfc469b1a.json']

# %%
# Get the process ID (PID) of a process by name
process_name = "python3"
for proc in psutil.process_iter(["name"]):
    if proc.info["name"] == process_name:
        print(f"PID of {process_name}: {proc.pid}")
# Out:
# PID of python3: 52102
# PID of python3: 62567

# %%
# Get the network usage for a given network interface

net_io_counters = psutil.net_io_counters(pernic=True)

net_io_counters
# Out:
# {'lo': snetio(bytes_sent=1628411527, bytes_recv=1628411527, packets_sent=372785, packets_recv=372785, errin=0, errout=0, dropin=0, dropout=0),
#  'eth0': snetio(bytes_sent=832307977, bytes_recv=25463125077, packets_sent=792616, packets_recv=18502717, errin=0, errout=0, dropin=0, dropout=0),
#  'docker0': snetio(bytes_sent=0, bytes_recv=0, packets_sent=0, packets_recv=0, errin=0, errout=0, dropin=0, dropout=0)}

# %%
for interface in net_io_counters:
    print(f"\nBytes sent  : {net_io_counters[interface].bytes_sent}")
    print(f"Bytes received: {net_io_counters[interface].bytes_recv}")
    print(f"Packets sent  : {net_io_counters[interface].packets_sent}")
    print(f"Packets received: {net_io_counters[interface].packets_recv}")
    print(f"DropIn        : {net_io_counters[interface].dropin}")
    print(f"DropOut       : {net_io_counters[interface].dropout}")
    print(f"count         : {net_io_counters[interface].count}")
# Out:
# Bytes sent  : 1628411527
# Bytes received: 1628411527
# Packets sent  : 372785
# Packets received: 372785
# DropIn        : 0
# DropOut       : 0
# count         : <built-in method count of snetio object at 0x7a2a803105f0>
#
# Bytes sent  : 832307977
# Bytes received: 25463125077
# Packets sent  : 792616
# Packets received: 18502717
# DropIn        : 0
# DropOut       : 0
# count         : <built-in method count of snetio object at 0x7a2a80310890>
#
# Bytes sent  : 0
# Bytes received: 0
# Packets sent  : 0
# Packets received: 0
# DropIn        : 0
# DropOut       : 0
# count         : <built-in method count of snetio object at 0x7a2a80310820>

# %%
num_connections = len(psutil.net_connections())
print(f"Number of connections: {num_connections}")
# Out:
# Number of connections: 63

# %%
# Get the list of mounted file systems

partitions = psutil.disk_partitions(all=True)
for partition in partitions:
    print(partition.mountpoint)
# Out:
# /
# /proc
# /dev
# /dev/pts
# /sys
# /sys/fs/cgroup
# /dev/mqueue
# /dev/shm
# /usr/sbin/docker-init
# /vscode
# /workspaces
# /tmp
# /.codespaces/bin
# /etc/resolv.conf
# /etc/hostname
# /etc/hosts
# /var/lib/docker
# /workspaces/.codespaces/.persistedshare
# /workspaces/.codespaces/shared
# /home/vscode/.minikube
# /sys/kernel/security

# %%
battery = psutil.sensors_battery()
if battery is not None:
    plugged = "Plugged in" if battery.power_plugged else "Not plugged in"
    print(f"Battery level: {battery.percent}% ({plugged})")
else:
    print("Battery information not available")
# Out:
# Battery information not available
