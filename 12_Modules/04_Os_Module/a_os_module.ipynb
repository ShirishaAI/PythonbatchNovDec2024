# %% [markdown]
# os module

# %%
import os

# %%
os
# Out:
# <module 'os' (frozen)>

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_KILLED',
#  'CLD_STOPPED',
#  'CLD_TRAPPED',
#  'CLONE_FILES',
#  'CLONE_FS',
#  'CLONE_NEWCGROUP',
#  'CLONE_NEWIPC',
#  'CLONE_NEWNET',
#  'CLONE_NEWNS',
#  'CLONE_NEWPID',
#  'CLONE_NEWUSER',
#  'CLONE_NEWUTS',
#  'CLONE_SIGHAND',
#  'CLONE_SYSVSEM',
#  'CLONE_THREAD',
#  'CLONE_VM',
#  'DirEntry',
#  'EFD_CLOEXEC',
#  'EFD_NONBLOCK',
#  'EFD_SEMAPHORE',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GRND_NONBLOCK',
#  'GRND_RANDOM',
#  'GenericAlias',
#  'MFD_ALLOW_SEALING',
#  'MFD_CLOEXEC',
#  'MFD_HUGETLB',
#  'MFD_HUGE_16GB',
#  'MFD_HUGE_16MB',
#  'MFD_HUGE_1GB',
#  'MFD_HUGE_1MB',
#  'MFD_HUGE_256MB',
#  'MFD_HUGE_2GB',
#  'MFD_HUGE_2MB',
#  'MFD_HUGE_32MB',
#  'MFD_HUGE_512KB',
#  'MFD_HUGE_512MB',
#  'MFD_HUGE_64KB',
#  'MFD_HUGE_8MB',
#  'MFD_HUGE_MASK',
#  'MFD_HUGE_SHIFT',
#  'Mapping',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EXCL',
#  'O_FSYNC',
#  'O_LARGEFILE',
#  'O_NDELAY',
#  'O_NOATIME',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NONBLOCK',
#  'O_PATH',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_RSYNC',
#  'O_SYNC',
#  'O_TMPFILE',
#  'O_TRUNC',
#  'O_WRONLY',
#  'POSIX_FADV_DONTNEED',
#  'POSIX_FADV_NOREUSE',
#  'POSIX_FADV_NORMAL',
#  'POSIX_FADV_RANDOM',
#  'POSIX_FADV_SEQUENTIAL',
#  'POSIX_FADV_WILLNEED',
#  'POSIX_SPAWN_CLOSE',
#  'POSIX_SPAWN_DUP2',
#  'POSIX_SPAWN_OPEN',
#  'PRIO_PGRP',
#  'PRIO_PROCESS',
#  'PRIO_USER',
#  'P_ALL',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_PGID',
#  'P_PID',
#  'P_PIDFD',
#  'P_WAIT',
#  'PathLike',
#  'RTLD_DEEPBIND',
#  'RTLD_GLOBAL',
#  'RTLD_LAZY',
#  'RTLD_LOCAL',
#  'RTLD_NODELETE',
#  'RTLD_NOLOAD',
#  'RTLD_NOW',
#  'RWF_APPEND',
#  'RWF_DSYNC',
#  'RWF_HIPRI',
#  'RWF_NOWAIT',
#  'RWF_SYNC',
#  'R_OK',
#  'SCHED_BATCH',
#  'SCHED_FIFO',
#  'SCHED_IDLE',
#  'SCHED_OTHER',
#  'SCHED_RESET_ON_FORK',
#  'SCHED_RR',
#  'SEEK_CUR',
#  'SEEK_DATA',
#  'SEEK_END',
#  'SEEK_HOLE',
#  'SEEK_SET',
#  'SPLICE_F_MORE',
#  'SPLICE_F_MOVE',
#  'SPLICE_F_NONBLOCK',
#  'ST_APPEND',
#  'ST_MANDLOCK',
#  'ST_NOATIME',
#  'ST_NODEV',
#  'ST_NODIRATIME',
#  'ST_NOEXEC',
#  'ST_NOSUID',
#  'ST_RDONLY',
#  'ST_RELATIME',
#  'ST_SYNCHRONOUS',
#  'ST_WRITE',
#  'TMP_MAX',
#  'WCONTINUED',
#  'WCOREDUMP',
#  'WEXITED',
#  'WEXITSTATUS',
#  'WIFCONTINUED',
#  'WIFEXITED',
#  'WIFSIGNALED',
#  'WIFSTOPPED',
#  'WNOHANG',
#  'WNOWAIT',
#  'WSTOPPED',
#  'WSTOPSIG',
#  'WTERMSIG',
#  'WUNTRACED',
#  'W_OK',
#  'XATTR_CREATE',
#  'XATTR_REPLACE',
#  'XATTR_SIZE_MAX',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_fwalk',
#  '_get_exports_list',
#  '_spawnvef',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'chown',
#  'chroot',
#  'close',
#  'closerange',
#  'confstr',
#  'confstr_names',
#  'copy_file_range',
#  'cpu_count',
#  'ctermid',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'environb',
#  'error',
#  'eventfd',
#  'eventfd_read',
#  'eventfd_write',
#  'execl',
#  'execle',
#  'execlp',
#  'execlpe',
#  'execv',
#  'execve',
#  'execvp',
#  'execvpe',
#  'extsep',
#  'fchdir',
#  'fchmod',
#  'fchown',
#  'fdatasync',
#  'fdopen',
#  'fork',
#  'forkpty',
#  'fpathconf',
#  'fsdecode',
#  'fsencode',
#  'fspath',
#  'fstat',
#  'fstatvfs',
#  'fsync',
#  'ftruncate',
#  'fwalk',
#  'get_blocking',
#  'get_exec_path',
#  'get_inheritable',
#  'get_terminal_size',
#  'getcwd',
#  'getcwdb',
#  'getegid',
#  'getenv',
#  'getenvb',
#  'geteuid',
#  'getgid',
#  'getgrouplist',
#  'getgroups',
#  'getloadavg',
#  'getlogin',
#  'getpgid',
#  'getpgrp',
#  'getpid',
#  'getppid',
#  'getpriority',
#  'getrandom',
#  'getresgid',
#  'getresuid',
#  'getsid',
#  'getuid',
#  'getxattr',
#  'initgroups',
#  'isatty',
#  'kill',
#  'killpg',
#  'lchown',
#  'linesep',
#  'link',
#  'listdir',
#  'listxattr',
#  'lockf',
#  'login_tty',
#  'lseek',
#  'lstat',
#  'major',
#  'makedev',
#  'makedirs',
#  'memfd_create',
#  'minor',
#  'mkdir',
#  'mkfifo',
#  'mknod',
#  'name',
#  'nice',
#  'open',
#  'openpty',
#  'pardir',
#  'path',
#  'pathconf',
#  'pathconf_names',
#  'pathsep',
#  'pidfd_open',
#  'pipe',
#  'pipe2',
#  'popen',
#  'posix_fadvise',
#  'posix_fallocate',
#  'posix_spawn',
#  'posix_spawnp',
#  'pread',
#  'preadv',
#  'putenv',
#  'pwrite',
#  'pwritev',
#  'read',
#  'readlink',
#  'readv',
#  'register_at_fork',
#  'remove',
#  'removedirs',
#  'removexattr',
#  'rename',
#  'renames',
#  'replace',
#  'rmdir',
#  'scandir',
#  'sched_get_priority_max',
#  'sched_get_priority_min',
#  'sched_getaffinity',
#  'sched_getparam',
#  'sched_getscheduler',
#  'sched_param',
#  'sched_rr_get_interval',
#  'sched_setaffinity',
#  'sched_setparam',
#  'sched_setscheduler',
#  'sched_yield',
#  'sendfile',
#  'sep',
#  'set_blocking',
#  'set_inheritable',
#  'setegid',
#  'seteuid',
#  'setgid',
#  'setgroups',
#  'setns',
#  'setpgid',
#  'setpgrp',
#  'setpriority',
#  'setregid',
#  'setresgid',
#  'setresuid',
#  'setreuid',
#  'setsid',
#  'setuid',
#  'setxattr',
#  'spawnl',
#  'spawnle',
#  'spawnlp',
#  'spawnlpe',
#  'spawnv',
#  'spawnve',
#  'spawnvp',
#  'spawnvpe',
#  'splice',
#  'st',
#  'stat',
#  'stat_result',
#  'statvfs',
#  'statvfs_result',
#  'strerror',
#  'supports_bytes_environ',
#  'supports_dir_fd',
#  'supports_effective_ids',
#  'supports_fd',
#  'supports_follow_symlinks',
#  'symlink',
#  'sync',
#  'sys',
#  'sysconf',
#  'sysconf_names',
#  'system',
#  'tcgetpgrp',
#  'tcsetpgrp',
#  'terminal_size',
#  'times',
#  'times_result',
#  'truncate',
#  'ttyname',
#  'umask',
#  'uname',
#  'uname_result',
#  'unlink',
#  'unsetenv',
#  'unshare',
#  'urandom',
#  'utime',
#  'wait',
#  'wait3',
#  'wait4',
#  'waitid',
#  'waitid_result',
#  'waitpid',
#  'waitstatus_to_exitcode',
#  'walk',
#  'write',
#  'writev']

# %%
print(os.__doc__)
# Out:
# OS routines for NT or Posix depending on what system we're on.
#
# This exports:
#   - all functions from posix or nt, e.g. unlink, stat, etc.
#   - os.path is either posixpath or ntpath
#   - os.name is either 'posix' or 'nt'
#   - os.curdir is a string representing the current directory (always '.')
#   - os.pardir is a string representing the parent directory (always '..')
#   - os.sep is the (or a most common) pathname separator ('/' or '\\')
#   - os.extsep is the extension separator (always '.')
#   - os.altsep is the alternate pathname separator (None or '/')
#   - os.pathsep is the component separator used in $PATH etc
#   - os.linesep is the line separator in text files ('\r' or '\n' or '\r\n')
#   - os.defpath is the default search path for executables
#   - os.devnull is the file path of the null device ('/dev/null', etc.)
#
# Programs that import and use 'os' stand a better chance of being
# portable between different platforms.  Of course, they must then
# only use functions that are defined by all platforms (e.g., unlink
# and opendir), and leave all pathname manipulation to os.path
# (e.g., split and join).

# %%
print(f"There are {os.cpu_count()} CPU's in this system.")
# Out:
# There are 2 CPU's in this system.

# %%
try:
    f"logged_in_user_name is {os.getlogin()}"
except OSError as ex:
    print(ex)
# Out:
# [Errno 6] No such device or address

# %%
print(f"Here is a proper 10-byte random number: {str(os.urandom(10))}.")
# Out:
# Here is a proper 10-byte random number: b'\xdf2\x9e|\x17n|\x1f\x0b:'.

# %%
print(f"Here is a proper 10-byte random number: {str(os.urandom(10))}.")
# Out:
# Here is a proper 10-byte random number: b';\x1f\xcf\x05?\x18h\x19L='.

# %%
print(f"Here is a proper 10-byte random number: {str(os.urandom(10))}.")
# Out:
# Here is a proper 10-byte random number: b'!Y\x9a\xc0\xcf\xe9\x0c\xf8\xcf\x14'.

# %%
print(
    f""" 
{os.altsep =}
{os.curdir =}
{os.extsep =}
{os.linesep=}
{os.name   =}
{os.pardir =}
{os.pathsep=}
{os.sep    =}
"""
)
# Out:
#
# os.altsep =None
# os.curdir ='.'
# os.extsep ='.'
# os.linesep='\n'
# os.name   ='posix'
# os.pardir ='..'
# os.pathsep=':'
# os.sep    ='/'

# %%
os.name
# The name of the operating system dependent module imported.
# The following names have currently been registered: 'posix', 'nt', 'java'.
# Out:
# 'posix'

# %%
os.devnull 
# The file path of the null device. For example: '/dev/null' for POSIX, 'nul' for Windows
# Out:
# '/dev/null'

# %%
os.defpath
# Out:
# '/bin:/usr/bin'

# %% [markdown]
# os.times
#
#     user            - user time
#     system          - system time
#     children_user   - user time of all child processes
#     children_system - system time of all child processes
#     elapsed         - elapsed real time since a fixed point in the past

# %%
os.times()
# Out:
# posix.times_result(user=0.74, system=0.14, children_user=0.0, children_system=0.0, elapsed=17184676.44)

# %%
os.urandom(10)
# Out:
# b'\xbf\x8bk\xec*\x01OR\tQ'

# %%
os.urandom(10)
# Out:
# b'\x19\xb0\xb1y\xd3\xa9\n\x86^B'

# %%
os.getenv("PYTHON_PATH", "No Set Yet")
# Out:
# '/usr/local/python/current'

# %%
# export PYTHONSTARTUP=/path/to/your/script.py
# set PYTHONSTARTUP=C:\path\to\your\script.py

# If set, that script will execute, everytime a new interactive mode of Python is started

os.getenv("PYTHONSTARTUP", "Not Set Yet")
# Out:
# 'Not Set Yet'

# %%
os.getenv("TEMP")

# %%
# Adding new environment variable

os.putenv("A", "Apple")  # wont change the

os.getenv("A", "No such key")
# Out:
# 'No such key'

# %%
os.environ["A"] = "Apple"  # modifies environment variables

os.getenv("A", "No such key")
# Out:
# 'Apple'

# %%
for each_path in sorted(os.get_exec_path()):
    print(each_path)
# Returns the list of directories that will be searched for a named executable, when launching a process.
# Out:
# /bin
# /bin
# /go/bin
# /go/bin
# /home/codespace/.dotnet
# /home/codespace/.dotnet
# /home/codespace/.dotnet/tools
# /home/codespace/.dotnet/tools
# /home/codespace/.local/bin
# /home/codespace/.local/bin
# /home/codespace/.local/bin
# /home/codespace/.local/bin
# /home/codespace/.php/current/bin
# /home/codespace/.php/current/bin
# /home/codespace/.python/current/bin
# /home/codespace/.python/current/bin
# /home/codespace/.python/current/bin
# /home/codespace/.ruby/current/bin
# /home/codespace/.ruby/current/bin
# /home/codespace/java/current/bin
# /home/codespace/java/current/bin
# /home/codespace/nvm/current/bin
# /home/codespace/nvm/current/bin
# /opt/conda/bin
# /opt/conda/bin
# /sbin
# /sbin
# /usr/bin
# /usr/bin
# /usr/local/bin
# /usr/local/bin
# /usr/local/go/bin
# /usr/local/go/bin
# /usr/local/hugo/bin
# /usr/local/hugo/bin
# /usr/local/nvs
# /usr/local/nvs
# /usr/local/oryx
# /usr/local/oryx
# /usr/local/php/current/bin
# /usr/local/php/current/bin
# /usr/local/py-utils/bin
# /usr/local/py-utils/bin
# /usr/local/python/current/bin
# /usr/local/python/current/bin
# /usr/local/rvm/bin
# /usr/local/rvm/bin
# /usr/local/rvm/gems/default/bin
# /usr/local/rvm/gems/default/bin
# /usr/local/rvm/gems/default@global/bin
# /usr/local/rvm/gems/default@global/bin
# /usr/local/rvm/rubies/default/bin
# /usr/local/rvm/rubies/default/bin
# /usr/local/sbin
# /usr/local/sbin
# /usr/local/sdkman/bin
# /usr/local/sdkman/bin
# /usr/local/sdkman/candidates/ant/current/bin
# /usr/local/sdkman/candidates/ant/current/bin
# /usr/local/sdkman/candidates/gradle/current/bin
# /usr/local/sdkman/candidates/gradle/current/bin
# /usr/local/sdkman/candidates/java/current/bin
# /usr/local/sdkman/candidates/java/current/bin
# /usr/local/sdkman/candidates/maven/current/bin
# /usr/local/sdkman/candidates/maven/current/bin
# /usr/local/share/nvm/current/bin
# /usr/local/share/nvm/current/bin
# /usr/local/share/rbenv/bin
# /usr/local/share/rbenv/bin
# /usr/sbin
# /usr/sbin
# /usr/share/dotnet
# /usr/share/dotnet
# /vscode/bin/linux-x64/fabdb6a30b49f79a7aba0f2ad9df9b399473380f/bin/remote-cli
# /vscode/bin/linux-x64/fabdb6a30b49f79a7aba0f2ad9df9b399473380f/bin/remote-cli

# %%
os.getpid()  # Return the parent’s process id.
# Out:
# 33353

# %%
os.getcwd()
# Out:
# '/workspaces/PythonbatchNovDec2024/12_Modules/04_Os_Module'

# %%
print("my\newfolder")
# Out:
# my
# ewfolder

# %%
print("my\\newfolder")
# Out:
# my\newfolder

# %%
print(r"my\newfolder")
# Out:
# my\newfolder

# %%
print(r"my\newfolde\sdas\asd\asd\asd\asdasd\asd\asd")
# Out:
# my\newfolde\sdas\asd\asd\asd\asdasd\asd\asd

# %%
print("my/newfol/der")  # POSIX paths works in NT also
# Out:
# my/newfol/der

# %%
os.getcwd()
# Out:
# '/workspaces/PythonbatchNovDec2024/12_Modules/04_Os_Module'

# %%
os.listdir()
# Out:
# ['a_os_module.ipynb']

# %%
os.listdir('.')
# Out:
# ['a_os_module.ipynb']

# %%
os.listdir(os.curdir)
# Out:
# ['a_os_module.ipynb']

# %%
assert os.listdir('..') == os.listdir(os.pardir)

# %%
os.listdir('..')
# Out:
# ['04_Os_Module', '05_psutil', '02_sys', '03_Argparse', '06_pathlib', '01_Math']

# %%
os.listdir('../..')
# Out:
# ['07_functions_decorators',
#  '00_course_details',
#  'class05',
#  '10_Generators',
#  '03_Language_components',
#  '01_Introduction',
#  '11_Coroutines',
#  '12_Modules',
#  '.git',
#  '.gitignore',
#  '02_Basics',
#  '06_Collections',
#  '09_Iterators_generators_coroutines',
#  '05_Debugging',
#  'README.md',
#  '04_Exceptions']

# %%
os.listdir('../../..')
# Out:
# ['.oryx', '.codespaces', 'PythonbatchNovDec2024']

# %%
os.chdir('../../..')

# %%
os.getcwd()
# Out:
# '/workspaces'

# %%
os.listdir()
# Out:
# ['.oryx', '.codespaces', 'PythonbatchNovDec2024']

# %%
os.chdir('/workspaces/PythonbatchNovDec2024/12_Modules')
os.chdir('04_Os_Module')

# %%
os.getcwd()
# Out:
# '/workspaces/PythonbatchNovDec2024/12_Modules/04_Os_Module'

# %%
os.scandir(os.getcwd())
# os.listdir returns a list, whereas os.scandir will return iterator object
# Also, os.scandir is faster and provides info about files like file size, creation time, etc

# %%
for entry in os.scandir(os.getcwd()):
    if entry.is_file():
        print(f"File: {entry.name}")
    elif entry.is_dir():
        print(f"Directory: {entry.name}")
# Out:
# File: a_os_module.ipynb

# %%
os.lstat(".")
# Out:
# os.stat_result(st_mode=16895, st_ino=1835543, st_dev=1797, st_nlink=2, st_uid=1000, st_gid=1000, st_size=4096, st_atime=1736224884, st_mtime=1736224883, st_ctime=1736224883)

# %%
from datetime import datetime, UTC

time_stamp = os.lstat(".").st_mtime

print(datetime.fromtimestamp(time_stamp, UTC))
# Out:
# 2025-01-07 04:41:23.339739+00:00

# %% [markdown]
# working with paths

# %%
print(
    f"""
    os.curdir : {os.curdir}
    os.pardir : {os.pardir}
    os.sep    : {os.sep}
    os.altsep : {os.altsep}
    os.extsep : {os.extsep}
    os.pathsep: {os.pathsep}  # ':' for POSIX or ';' for Windows
"""
)
# Out:
#     os.curdir : .
#     os.pardir : ..
#     os.sep    : /
#     os.altsep : None
#     os.extsep : .
#     os.pathsep: :  # ':' for POSIX or ';' for Windows

# %%
os.linesep  # '\n' for POSIX, '\r\n' for Windows
# Out:
# '\n'

# %% [markdown]
# working with directories/folder

# %%
os.mkdir('myFolder')

# %%
os.listdir('.')
# Out:
# ['a_os_module.ipynb', 'myFolder']

# %%
os.mkdir('myFolder')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 os.mkdir('myFolder')
#
# FileExistsError: [Errno 17] File exists: 'myFolder'

# %%
os.mkdir?
# Out:
# Signature: os.mkdir(path, mode=511, *, dir_fd=None)
# Docstring:
# Create a directory.
#
# If dir_fd is not None, it should be a file descriptor open to a directory,
#   and path should be relative; path will then be relative to that directory.
# dir_fd may not be implemented on your platform.
#   If it is unavailable, using it will raise a NotImplementedError.
#
# The mode argument is ignored on Windows. Where it is used, the current umask
# value is first masked out.
# Type:      builtin_function_or_method

# %%
os.makedirs('myFolder')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 os.makedirs('myFolder')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: 'myFolder'

# %%
os.makedirs?
# Out:
# Signature: os.makedirs(name, mode=511, exist_ok=False)
# Docstring:
# makedirs(name [, mode=0o777][, exist_ok=False])
#
# Super-mkdir; create a leaf directory and all intermediate ones.  Works like
# mkdir, except that any intermediate path segment (not just the rightmost)
# will be created if it does not exist. If the target directory already
# exists, raise an OSError if exist_ok is False. Otherwise no exception is
# raised.  This is recursive.
# File:      /workspaces/PythonbatchNovDec2024/12_Modules/04_Os_Module/<frozen os>
# Type:      function

# %%
os.makedirs('myFolder', exist_ok=True)

# %%
os.makedirs('First/Second/Third', exist_ok=True)

# %%
os.listdir()
# Out:
# ['a_os_module.ipynb', 'First', 'myFolder']

# %%
os.system('tree')
# Out:
# .
# ├── First
# │   └── Second
# │       └── Third
# ├── a_os_module.ipynb
# └── myFolder
#
# 4 directories, 1 file
# 0

# %%
# creating a file
f = open("myfile.txt", "w")
f.write("my data")
f.close()

# %%
os.listdir()
# Out:
# ['a_os_module.ipynb', 'myfile.txt', 'First', 'myFolder']

# %%
os.rename("myfile.txt", "otherfile.tsf")

# %%
os.listdir()
# Out:
# ['otherfile.tsf', 'a_os_module.ipynb', 'First', 'myFolder']

# %%
os.rename("First", "PythonFolder")

# %%
os.system('tree')
# Out:
# .
# ├── PythonFolder
# │   └── Second
# │       └── Third
# ├── a_os_module.ipynb
# ├── myFolder
# └── otherfile.tsf
#
# 4 directories, 2 files
# 0

# %%
? os.renames
# Out:
# Signature:  os.renames(old, new)
# Docstring:
# renames(old, new)
#
# Super-rename; create directories as necessary and delete any left
# empty.  Works like rename, except creation of any intermediate
# directories needed to make the new pathname good is attempted
# first.  After the rename, directories corresponding to rightmost
# path segments of the old name will be pruned until either the
# whole path is consumed or a nonempty directory is found.
#
# Note: this function can fail with the new directory structure made
# if you lack permissions needed to unlink the leaf directory or
# file.
# File:      /workspaces/PythonbatchNovDec2024/12_Modules/04_Os_Module/<frozen os>
# Type:      function

# %%
# assignment - try this os.renames
os.rename("PythonFolder/Second", "PythonFolder/SubFolder1")

# %%
os.system('tree')
# Out:
# .
# ├── PythonFolder
# │   └── SubFolder1
# │       └── Third
# ├── a_os_module.ipynb
# ├── myFolder
# └── otherfile.tsf
#
# 4 directories, 2 files
# 0

# %%
os.remove("otherfile.tsf")

# %%
try:
    os.remove("myFolder")
except (PermissionError, IsADirectoryError) as ex:
    print(repr(ex))
# Out:
# IsADirectoryError(21, 'Is a directory')

# %%
os.rmdir("myFolder")

# %%
os.system('tree')
# Out:
# .
# ├── PythonFolder
# │   └── SubFolder1
# │       └── Third
# └── a_os_module.ipynb
#
# 3 directories, 1 file
# 0

# %%
os.removedirs("PythonFolder/SubFolder1/Third")
# first removes 'PythonFolder/SubFolder1/Third', 
# then 'PythonFolder/SubFolder1' 
# and then 'PythonFolder'

# %%
os.system('tree')
# Out:
# .
# └── a_os_module.ipynb
#
# 0 directories, 1 file
# 0

# %% [markdown]
# Executing commands

# %%
os.system("ipconfig")
# Out:
# sh: 1: ipconfig: not found
# 32512

# %%
os.system("ifconfig")
# Out:
# docker0: flags=4099<UP,BROADCAST,MULTICAST>  mtu 1500
#         inet 172.17.0.1  netmask 255.255.0.0  broadcast 172.17.255.255
#         ether 02:42:a8:41:b8:79  txqueuelen 0  (Ethernet)
#         RX packets 0  bytes 0 (0.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 0  bytes 0 (0.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 10.0.0.67  netmask 255.255.0.0  broadcast 10.0.255.255
#         inet6 fe80::6245:bdff:fea6:f336  prefixlen 64  scopeid 0x20<link>
#         ether 60:45:bd:a6:f3:36  txqueuelen 1000  (Ethernet)
#         RX packets 17652450  bytes 24457546265 (24.4 GB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 545516  bytes 239972385 (239.9 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 137558  bytes 143281185 (143.2 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 137558  bytes 143281185 (143.2 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
# 0

# %%
os.system("ping google.com")
# Out:
# sh: 1: ping: not found
# 32512

# %% [markdown]
# Get all the python files in our material

# %%
os.listdir('../../../PythonbatchNovDec2024')
# Out:
# ['07_functions_decorators',
#  '00_course_details',
#  'class05',
#  '10_Generators',
#  '03_Language_components',
#  '01_Introduction',
#  '11_Coroutines',
#  '12_Modules',
#  '.git',
#  '.gitignore',
#  '02_Basics',
#  '06_Collections',
#  '09_Iterators_generators_coroutines',
#  '05_Debugging',
#  'README.md',
#  '04_Exceptions']

# %%
# os.walk(top, topdown=True, onerror=None, followlinks=False)


os.walk('../../../PythonbatchNovDec2024')
# Out:
# <generator object walk at 0x74aa88232cd0>

# %%
for each in os.walk("."):
    print(len(each), each)
    # break
# Out:
# 3 ('.', [], ['a_os_module.ipynb'])

# %%
for each_dir, list_of_folders, list_of_files in os.walk('../../../PythonbatchNovDec2024'):
    print(each_dir)
# Out:
# ../../../PythonbatchNovDec2024
# ../../../PythonbatchNovDec2024/07_functions_decorators
# ../../../PythonbatchNovDec2024/00_course_details
# ../../../PythonbatchNovDec2024/class05
# ../../../PythonbatchNovDec2024/10_Generators
# ../../../PythonbatchNovDec2024/10_Generators/10_generators
# ../../../PythonbatchNovDec2024/03_Language_components
# ../../../PythonbatchNovDec2024/03_Language_components/08_Structural_pattern_matching
# ../../../PythonbatchNovDec2024/03_Language_components/09_Loops
# ../../../PythonbatchNovDec2024/03_Language_components/03_Boolean_operations
# ../../../PythonbatchNovDec2024/03_Language_components/06_Range_function
# ../../../PythonbatchNovDec2024/03_Language_components/05_Identify_operations
# ../../../PythonbatchNovDec2024/03_Language_components/02_Logical_operations
# ../../../PythonbatchNovDec2024/03_Language_components/04_Bitwise_operations
# ../../../PythonbatchNovDec2024/03_Language_components/01_Relational_operations
# ../../../PythonbatchNovDec2024/03_Language_components/07_Conditional_operations
# ../../../PythonbatchNovDec2024/03_Language_components/10_walrus_operator
# ../../../PythonbatchNovDec2024/01_Introduction
# ../../../PythonbatchNovDec2024/11_Coroutines
# ../../../PythonbatchNovDec2024/12_Modules
# ../../../PythonbatchNovDec2024/12_Modules/04_Os_Module
# ../../../PythonbatchNovDec2024/12_Modules/05_psutil
# ../../../PythonbatchNovDec2024/12_Modules/02_sys
# ../../../PythonbatchNovDec2024/12_Modules/03_Argparse
# ../../../PythonbatchNovDec2024/12_Modules/06_pathlib
# ../../../PythonbatchNovDec2024/12_Modules/01_Math
# ../../../PythonbatchNovDec2024/.git
# ../../../PythonbatchNovDec2024/.git/objects
# ../../../PythonbatchNovDec2024/.git/objects/dd
# ../../../PythonbatchNovDec2024/.git/objects/2b
# ../../../PythonbatchNovDec2024/.git/objects/a1
# ../../../PythonbatchNovDec2024/.git/objects/77
# ../../../PythonbatchNovDec2024/.git/objects/b0
# ../../../PythonbatchNovDec2024/.git/objects/ae
# ../../../PythonbatchNovDec2024/.git/objects/8c
# ../../../PythonbatchNovDec2024/.git/objects/aa
# ../../../PythonbatchNovDec2024/.git/objects/c8
# ../../../PythonbatchNovDec2024/.git/objects/ce
# ../../../PythonbatchNovDec2024/.git/objects/e4
# ../../../PythonbatchNovDec2024/.git/objects/a0
# ../../../PythonbatchNovDec2024/.git/objects/da
# ../../../PythonbatchNovDec2024/.git/objects/04
# ../../../PythonbatchNovDec2024/.git/objects/6c
# ../../../PythonbatchNovDec2024/.git/objects/5c
# ../../../PythonbatchNovDec2024/.git/objects/16
# ../../../PythonbatchNovDec2024/.git/objects/0b
# ../../../PythonbatchNovDec2024/.git/objects/d4
# ../../../PythonbatchNovDec2024/.git/objects/51
# ../../../PythonbatchNovDec2024/.git/objects/1f
# ../../../PythonbatchNovDec2024/.git/objects/3a
# ../../../PythonbatchNovDec2024/.git/objects/dc
# ../../../PythonbatchNovDec2024/.git/objects/ff
# ../../../PythonbatchNovDec2024/.git/objects/90
# ../../../PythonbatchNovDec2024/.git/objects/be
# ../../../PythonbatchNovDec2024/.git/objects/73
# ../../../PythonbatchNovDec2024/.git/objects/c9
# ../../../PythonbatchNovDec2024/.git/objects/6e
# ../../../PythonbatchNovDec2024/.git/objects/93
# ../../../PythonbatchNovDec2024/.git/objects/69
# ../../../PythonbatchNovDec2024/.git/objects/e5
# ../../../PythonbatchNovDec2024/.git/objects/f0
# ../../../PythonbatchNovDec2024/.git/objects/fd
# ../../../PythonbatchNovDec2024/.git/objects/4e
# ../../../PythonbatchNovDec2024/.git/objects/c5
# ../../../PythonbatchNovDec2024/.git/objects/45
# ../../../PythonbatchNovDec2024/.git/objects/4a
# ../../../PythonbatchNovDec2024/.git/objects/pack
# ../../../PythonbatchNovDec2024/.git/objects/03
# ../../../PythonbatchNovDec2024/.git/objects/a5
# ../../../PythonbatchNovDec2024/.git/objects/bc
# ../../../PythonbatchNovDec2024/.git/objects/b7
# ../../../PythonbatchNovDec2024/.git/objects/3c
# ../../../PythonbatchNovDec2024/.git/objects/2c
# ../../../PythonbatchNovDec2024/.git/objects/8d
# ../../../PythonbatchNovDec2024/.git/objects/ad
# ../../../PythonbatchNovDec2024/.git/objects/97
# ../../../PythonbatchNovDec2024/.git/objects/43
# ../../../PythonbatchNovDec2024/.git/objects/8a
# ../../../PythonbatchNovDec2024/.git/objects/26
# ../../../PythonbatchNovDec2024/.git/objects/7b
# ../../../PythonbatchNovDec2024/.git/objects/b3
# ../../../PythonbatchNovDec2024/.git/objects/0e
# ../../../PythonbatchNovDec2024/.git/objects/d6
# ../../../PythonbatchNovDec2024/.git/objects/ea
# ../../../PythonbatchNovDec2024/.git/objects/b1
# ../../../PythonbatchNovDec2024/.git/objects/3e
# ../../../PythonbatchNovDec2024/.git/objects/5b
# ../../../PythonbatchNovDec2024/.git/objects/fc
# ../../../PythonbatchNovDec2024/.git/objects/39
# ../../../PythonbatchNovDec2024/.git/objects/53
# ../../../PythonbatchNovDec2024/.git/objects/5e
# ../../../PythonbatchNovDec2024/.git/objects/cd
# ../../../PythonbatchNovDec2024/.git/objects/d9
# ../../../PythonbatchNovDec2024/.git/objects/84
# ../../../PythonbatchNovDec2024/.git/objects/c0
# ../../../PythonbatchNovDec2024/.git/objects/a2
# ../../../PythonbatchNovDec2024/.git/objects/61
# ../../../PythonbatchNovDec2024/.git/objects/22
# ../../../PythonbatchNovDec2024/.git/objects/5d
# ../../../PythonbatchNovDec2024/.git/objects/38
# ../../../PythonbatchNovDec2024/.git/objects/cc
# ../../../PythonbatchNovDec2024/.git/objects/af
# ../../../PythonbatchNovDec2024/.git/objects/36
# ../../../PythonbatchNovDec2024/.git/objects/81
# ../../../PythonbatchNovDec2024/.git/objects/b9
# ../../../PythonbatchNovDec2024/.git/objects/e6
# ../../../PythonbatchNovDec2024/.git/objects/ee
# ../../../PythonbatchNovDec2024/.git/objects/2e
# ../../../PythonbatchNovDec2024/.git/objects/91
# ../../../PythonbatchNovDec2024/.git/objects/28
# ../../../PythonbatchNovDec2024/.git/objects/79
# ../../../PythonbatchNovDec2024/.git/objects/d3
# ../../../PythonbatchNovDec2024/.git/objects/6d
# ../../../PythonbatchNovDec2024/.git/objects/60
# ../../../PythonbatchNovDec2024/.git/objects/33
# ../../../PythonbatchNovDec2024/.git/objects/bb
# ../../../PythonbatchNovDec2024/.git/objects/05
# ../../../PythonbatchNovDec2024/.git/objects/ed
# ../../../PythonbatchNovDec2024/.git/objects/72
# ../../../PythonbatchNovDec2024/.git/objects/e0
# ../../../PythonbatchNovDec2024/.git/objects/20
# ../../../PythonbatchNovDec2024/.git/objects/25
# ../../../PythonbatchNovDec2024/.git/objects/d2
# ../../../PythonbatchNovDec2024/.git/objects/c3
# ../../../PythonbatchNovDec2024/.git/objects/67
# ../../../PythonbatchNovDec2024/.git/objects/76
# ../../../PythonbatchNovDec2024/.git/objects/de
# ../../../PythonbatchNovDec2024/.git/objects/ca
# ../../../PythonbatchNovDec2024/.git/objects/b2
# ../../../PythonbatchNovDec2024/.git/objects/e8
# ../../../PythonbatchNovDec2024/.git/objects/e1
# ../../../PythonbatchNovDec2024/.git/objects/3f
# ../../../PythonbatchNovDec2024/.git/objects/78
# ../../../PythonbatchNovDec2024/.git/objects/e9
# ../../../PythonbatchNovDec2024/.git/objects/9a
# ../../../PythonbatchNovDec2024/.git/objects/99
# ../../../PythonbatchNovDec2024/.git/objects/68
# ../../../PythonbatchNovDec2024/.git/objects/ba
# ../../../PythonbatchNovDec2024/.git/objects/0f
# ../../../PythonbatchNovDec2024/.git/objects/08
# ../../../PythonbatchNovDec2024/.git/objects/c6
# ../../../PythonbatchNovDec2024/.git/objects/27
# ../../../PythonbatchNovDec2024/.git/objects/8f
# ../../../PythonbatchNovDec2024/.git/objects/70
# ../../../PythonbatchNovDec2024/.git/objects/d7
# ../../../PythonbatchNovDec2024/.git/objects/31
# ../../../PythonbatchNovDec2024/.git/objects/98
# ../../../PythonbatchNovDec2024/.git/objects/c4
# ../../../PythonbatchNovDec2024/.git/objects/47
# ../../../PythonbatchNovDec2024/.git/objects/fa
# ../../../PythonbatchNovDec2024/.git/objects/b5
# ../../../PythonbatchNovDec2024/.git/objects/10
# ../../../PythonbatchNovDec2024/.git/objects/a9
# ../../../PythonbatchNovDec2024/.git/objects/02
# ../../../PythonbatchNovDec2024/.git/objects/19
# ../../../PythonbatchNovDec2024/.git/objects/eb
# ../../../PythonbatchNovDec2024/.git/objects/09
# ../../../PythonbatchNovDec2024/.git/objects/46
# ../../../PythonbatchNovDec2024/.git/objects/e2
# ../../../PythonbatchNovDec2024/.git/objects/4d
# ../../../PythonbatchNovDec2024/.git/objects/cb
# ../../../PythonbatchNovDec2024/.git/objects/f9
# ../../../PythonbatchNovDec2024/.git/objects/74
# ../../../PythonbatchNovDec2024/.git/objects/57
# ../../../PythonbatchNovDec2024/.git/objects/f7
# ../../../PythonbatchNovDec2024/.git/objects/64
# ../../../PythonbatchNovDec2024/.git/objects/11
# ../../../PythonbatchNovDec2024/.git/objects/c1
# ../../../PythonbatchNovDec2024/.git/objects/55
# ../../../PythonbatchNovDec2024/.git/objects/50
# ../../../PythonbatchNovDec2024/.git/objects/info
# ../../../PythonbatchNovDec2024/.git/objects/7d
# ../../../PythonbatchNovDec2024/.git/hooks
# ../../../PythonbatchNovDec2024/.git/lfs
# ../../../PythonbatchNovDec2024/.git/lfs/tmp
# ../../../PythonbatchNovDec2024/.git/branches
# ../../../PythonbatchNovDec2024/.git/refs
# ../../../PythonbatchNovDec2024/.git/refs/heads
# ../../../PythonbatchNovDec2024/.git/refs/tags
# ../../../PythonbatchNovDec2024/.git/refs/remotes
# ../../../PythonbatchNovDec2024/.git/refs/remotes/origin
# ../../../PythonbatchNovDec2024/.git/logs
# ../../../PythonbatchNovDec2024/.git/logs/refs
# ../../../PythonbatchNovDec2024/.git/logs/refs/heads
# ../../../PythonbatchNovDec2024/.git/logs/refs/remotes
# ../../../PythonbatchNovDec2024/.git/logs/refs/remotes/origin
# ../../../PythonbatchNovDec2024/.git/info
# ../../../PythonbatchNovDec2024/02_Basics
# ../../../PythonbatchNovDec2024/02_Basics/02_String_operations
# ../../../PythonbatchNovDec2024/06_Collections
# ../../../PythonbatchNovDec2024/06_Collections/04_Dicts
# ../../../PythonbatchNovDec2024/06_Collections/03_Sets
# ../../../PythonbatchNovDec2024/06_Collections/02_Tuples
# ../../../PythonbatchNovDec2024/06_Collections/01_Lists
# ../../../PythonbatchNovDec2024/09_Iterators_generators_coroutines
# ../../../PythonbatchNovDec2024/09_Iterators_generators_coroutines/02_iterators
# ../../../PythonbatchNovDec2024/09_Iterators_generators_coroutines/01_iterables
# ../../../PythonbatchNovDec2024/05_Debugging
# ../../../PythonbatchNovDec2024/04_Exceptions

# %%
for each_dir, list_of_folders, list_of_files in os.walk('../../../PythonbatchNovDec2024'):
    if list_of_folders:
        print(list_of_folders)
# Out:
# ['07_functions_decorators', '00_course_details', 'class05', '10_Generators', '03_Language_components', '01_Introduction', '11_Coroutines', '12_Modules', '.git', '02_Basics', '06_Collections', '09_Iterators_generators_coroutines', '05_Debugging', '04_Exceptions']
# ['10_generators']
# ['08_Structural_pattern_matching', '09_Loops', '03_Boolean_operations', '06_Range_function', '05_Identify_operations', '02_Logical_operations', '04_Bitwise_operations', '01_Relational_operations', '07_Conditional_operations', '10_walrus_operator']
# ['04_Os_Module', '05_psutil', '02_sys', '03_Argparse', '06_pathlib', '01_Math']
# ['objects', 'hooks', 'lfs', 'branches', 'refs', 'logs', 'info']
# ['dd', '2b', 'a1', '77', 'b0', 'ae', '8c', 'aa', 'c8', 'ce', 'e4', 'a0', 'da', '04', '6c', '5c', '16', '0b', 'd4', '51', '1f', '3a', 'dc', 'ff', '90', 'be', '73', 'c9', '6e', '93', '69', 'e5', 'f0', 'fd', '4e', 'c5', '45', '4a', 'pack', '03', 'a5', 'bc', 'b7', '3c', '2c', '8d', 'ad', '97', '43', '8a', '26', '7b', 'b3', '0e', 'd6', 'ea', 'b1', '3e', '5b', 'fc', '39', '53', '5e', 'cd', 'd9', '84', 'c0', 'a2', '61', '22', '5d', '38', 'cc', 'af', '36', '81', 'b9', 'e6', 'ee', '2e', '91', '28', '79', 'd3', '6d', '60', '33', 'bb', '05', 'ed', '72', 'e0', '20', '25', 'd2', 'c3', '67', '76', 'de', 'ca', 'b2', 'e8', 'e1', '3f', '78', 'e9', '9a', '99', '68', 'ba', '0f', '08', 'c6', '27', '8f', '70', 'd7', '31', '98', 'c4', '47', 'fa', 'b5', '10', 'a9', '02', '19', 'eb', '09', '46', 'e2', '4d', 'cb', 'f9', '74', '57', 'f7', '64', '11', 'c1', '55', '50', 'info', '7d']
# ['tmp']
# ['heads', 'tags', 'remotes']
# ['origin']
# ['refs']
# ['heads', 'remotes']
# ['origin']
# ['02_String_operations']
# ['04_Dicts', '03_Sets', '02_Tuples', '01_Lists']
# ['02_iterators', '01_iterables']

# %%
for each_dir, list_of_folders, list_of_files in os.walk('../../../PythonbatchNovDec2024'):
    if list_of_files:
        print(list_of_files)
# Out:
# ['.gitignore', 'README.md']
# ['b_advanced.ipynb', 'a_functional programming.ipynb']
# ['Explanation.txt', 'course_content_txt']
# ['a_generators.ipynb']
# ['b_vowel_char_check.py', 'a_check_number.ipynb', 'c_office_schedule.py']
# ['e_multiplication_table.py', 'f_loops.py', 'b_progress_bar_implementation.py', 'd_while_loop.ipynb', 'c_progress_bar.py', 'a_for_loop.ipynb']
# ['a_boolean_operations.ipynb']
# ['a_range_function.ipynb']
# ['a_Identify_oprations.ipynb']
# ['c_short_circuit.py', 'a_logical_operations.py', 'b_logical_operations.py']
# ['a_bitwise_operations.ipynb']
# ['a_relational_operations.py']
# ['a_even_or_odd.py', 'e_celsius_to_fahrenheit_conversion.py', 'd_Vowels_and_consonants.py', 'f_Temperature_conversion.py', 'g_Electricity_bill_generation.py', 'c_office_schedule.py', 'b_Number_guessing_game.py']
# ['a_simple_usage.ipynb']
# ['f_print_syntax.py', 'd_indentation_issue.py', 'g2_print_syntax.ipynb', 'a_first.py', 'b_hello_world.py', 'e_built_in_functions.txt', 'c_dynamic_typing.py', 'g_print_syntax.py']
# ['a_coroutines.ipynb']
# ['a_os_module.ipynb']
# ['a_sys_module.ipynb', 'b_commandline.args.py']
# ['a_argparse.py']
# ['a_math_module.ipynb']
# ['config', 'index', 'packed-refs', 'ORIG_HEAD', 'HEAD', 'FETCH_HEAD', 'COMMIT_EDITMSG', 'description']
# ['38916d80b6df1563575a0284b95aba592628b7']
# ['79ec39ece189f9341f4706a1d9be7833b47012']
# ['fdedfc46035ec0450c2c0736a0b46ec7c30f37', 'e412c815f4a4a4c60204dca6cb935c33cbb347']
# ['cf5087a5038622bfa86c13959fc65947415762']
# ['dab089fa7a11847fa0429100710734f8483925']
# ['22817c6896d458b7d649b6a6501d184da9f86f']
# ['036e4938b1883e9e1ef3196afd36bdc45ed752']
# ['58f504a731d68203b3bea46a1851b53cf7a64b']
# ['9874b1b841daaafc9c007f6479410f730eee0f']
# ['75ac80e2e1d7929b5cf8f0b8572e9d9bfb1f8a']
# ['d0739003ac529cfab308beeed00376a8008ea0']
# ['fbc53f07d5825fdac25eaac65f412a5a01f32e', 'cf29c6086c28637383b313135d3941be070cd7', 'fbb6f2bb32ee3cf9ee86edb36ea64ac77dafa0']
# ['2c370632d7918b02f7c2da9b5230df46cc2d7c']
# ['641c86e6d09cb5c9d206d869973f142178fa2f']
# ['06ad4ed5e4d6b86649a3b78757c6788658282a']
# ['5ec4d3f1217b07a1fdb66a943f83186ac70a12', '433b8290db6a04bcbf96d1b657ece0f637e6e0']
# ['68cde66d4c535180a036dc2c13aa2741a52412']
# ['62d1e405c50adfe8c85abaa68d0ca06b4f4bdc']
# ['f74ad3c90b20ecd411d5d13afb7f0ebc6030d5', '02e90a90ec55164c6e62d1c953310d70227d8e']
# ['a83b70726135f2dfe6d5230d0d8f87b7c004b1']
# ['7b61a12feb4e692f7ac6275f585b09f9c7e491', 'b93937585a72f1d53a9f609a19923d8e0d6e84']
# ['35dc569ab73483377860500656b49103e25037', '3bcfb9ef29e044a2106b95bc83c6c586b3d529']
# ['a36f8a027902a286bd252efc4061d045775217']
# ['57cefbe8385846250be747ebc5ed91cd8cce7a']
# ['a8e9c31faf868144fdfc363e2f93dda62f7178', 'fb7b3ecc3f4d20013e8e06dd13be84884b8fb0', 'ef1ee9dc22805ad09024a24e3ca038372e6c4b']
# ['8a3cf92d0a1abd917cae0a67f02a90301194b1', '087ec5a596d72de76f60dfc61fb89eb6a24545', '17df9ef6f37479417197cb54bab014c7d8ac8e']
# ['72dbec42d4d09a5bba14dca2d26f41ab2eed3b']
# ['b11cd263258efa8ae799575bb5c6160f5ac4e2']
# ['87f25da6ac8277c032faa7f12e910ccbcbbb1e']
# ['2c0c00693abb18c0fbdeac3d26cb2c8a619ca1', 'be218fb24b8c0689cfa5568dd721117342a7c5', '34c006fc0d4b1ab5cfe4d5fc92e911e49cb048']
# ['0fc011b99102ebd4a22fc9eb5767b3ec6a9ba1']
# ['6464d37e4cf7a405a8d3668f07fd1c04d40a20']
# ['9c531f85b5650dad557a4ea358a012912d2b1b']
# ['f294c4aaacf12c944016eccc6d8fbddad7775e', 'd6eabf88b72cf34ccb75530ee172d61b7fc63d', '761449c32cba6c2256684bf55bba0b75bd723b']
# ['da1a8ee6616174c3873cd36406ab9e3666dd23']
# ['f0edfda57071376428dda161b237c122e1abd9', 'fc70bd489280f3e148759eb83002d3b74b2199']
# ['fab2cf9de1831a1f467e8c9415609fcff66e0f']
# ['6639a8f6ba823d9899c5c9015b007e733c8442']
# ['sendemail-validate.sample', 'post-update.sample', 'pre-push.sample', 'update.sample', 'pre-receive.sample', 'pre-rebase.sample', 'push-to-checkout.sample', 'applypatch-msg.sample', 'commit-msg.sample', 'pre-commit.sample', 'prepare-commit-msg.sample', 'pre-applypatch.sample', 'fsmonitor-watchman.sample', 'pre-merge-commit.sample']
# ['class05', 'class17', 'class14', 'class13', 'class01', 'class04', 'main', 'class21', 'class08', 'class16', 'class19', 'class15', 'class02', 'class20', 'class18', 'class23', 'class09', 'class10', 'class22', 'class12', 'class03', 'class11']
# ['class05', 'class17', 'class14', 'class01', 'class04', 'main', 'class21', 'class08', 'class16', 'class19', 'class15', 'class02', 'HEAD', 'class20', 'class18', 'class09', 'class10', 'class03', 'class11']
# ['HEAD']
# ['class05', 'class17', 'class14', 'class13', 'class01', 'class04', 'main', 'class21', 'class08', 'class16', 'class19', 'class15', 'class02', 'class20', 'class18', 'class23', 'class09', 'class10', 'class22', 'class12', 'class03', 'class11']
# ['class05', 'class17', 'class14', 'class01', 'class04', 'main', 'class21', 'class08', 'class16', 'class19', 'class15', 'class02', 'HEAD', 'class20', 'class18', 'class09', 'class10', 'class03', 'class11']
# ['exclude']
# ['usage_of_pydoc.txt', 'f_bytes_operations.ipynb', 'usage_of_help.py']
# ['Comprehensions.ipynb', 'a_dict_operations.ipynb', 'iterables_operations.ipynb']
# ['a_set_operations.ipynb', 'b_frozenset.ipynb', 'c_set.operators.ipynb']
# ['a_tuples.ipynb']
# ['a_list_operations.ipynb', 'b_copy_problem.ipynb']
# ['b_zip_map_filter.ipynb', 'a_range.ipynb', 'f_itertools_module.ipynb', 'c_user_defined_iterators.ipynb']
# ['a_Iterables.ipynb', 'explanation.txt']
# ['c_breakpoint_function.py', 'd_using_ipdb.py', '0_explanation.txt', 'b_breakpoint_function.py', 'a_using_pdb.py']
# ['01_exceptions_hierarchy.txt', '02_exceptions_handling.ipynb', '00_explanation.txt', '03_exceptions_hooks.py']

# %%
py_files = []
juypter_notebook_files = []

for each_dir, list_of_folders, list_of_files in os.walk('../../../PythonbatchNovDec2024'):
    if list_of_files:
        for each_file in list_of_files:
            file_name, file_extn = os.path.splitext(each_file)
            if file_extn == '.py':
                py_files.append(each_file)
            elif file_extn == '.ipynb':
                juypter_notebook_files.append(each_file)


print(
    f"In this course, there are {len(py_files)} python files & {len(juypter_notebook_files)} jupyter notebook files"
)
# Out:
# In this course, there are 31 python files & 32 jupyter notebook files

# %%
import os
# assignment - like a anti-virus scan, scan all the executables in your operating system. Based on OS, executable need to be taken
executable_count = 0
for root, dirs, files in os.walk('/'):
    for file in files:
        file_path = os.path.join(root, file)
        if os.access(file_path, os.X_OK):  #os.X_OK: Check if the file is executable.
            print(f"Found executable: {file_path}")
            executable_count += 1

print(f"\nTotal number of executables found: {executable_count}")
# Out:
# Found executable: /.dockerenv
# Found executable: /var/lib/dpkg/info/procps.preinst
# Found executable: /var/lib/dpkg/info/base-passwd.postrm
# Found executable: /var/lib/dpkg/info/adduser.postinst
# Found executable: /var/lib/dpkg/info/login.prerm
# Found executable: /var/lib/dpkg/info/passwd.prerm
# Found executable: /var/lib/dpkg/info/ubuntu-keyring.postinst
# Found executable: /var/lib/dpkg/info/debconf.preinst
# Found executable: /var/lib/dpkg/info/apt.preinst
# Found executable: /var/lib/dpkg/info/dash.config
# Found executable: /var/lib/dpkg/info/login.preinst
# Found executable: /var/lib/dpkg/info/dpkg.postinst
# Found executable: /var/lib/dpkg/info/util-linux.postinst
# Found executable: /var/lib/dpkg/info/bash.prerm
# Found executable: /var/lib/dpkg/info/util-linux.postrm
# Found executable: /var/lib/dpkg/info/login.postrm
# Found executable: /var/lib/dpkg/info/libpam0g:amd64.postinst
# Found executable: /var/lib/dpkg/info/apt.postrm
# Found executable: /var/lib/dpkg/info/dash.postrm
# Found executable: /var/lib/dpkg/info/adduser.postrm
# Found executable: /var/lib/dpkg/info/base-passwd.preinst
# Found executable: /var/lib/dpkg/info/libpam-runtime.prerm
# Found executable: /var/lib/dpkg/info/dash.postinst
# Found executable: /var/lib/dpkg/info/util-linux.prerm
# Found executable: /var/lib/dpkg/info/tar.prerm
# Found executable: /var/lib/dpkg/info/login.postinst
# Found executable: /var/lib/dpkg/info/debianutils.postinst
# Found executable: /var/lib/dpkg/info/dash.prerm
# Found executable: /var/lib/dpkg/info/mawk.postinst
# Found executable: /var/lib/dpkg/info/libc6:amd64.preinst
# Found executable: /var/lib/dpkg/info/libc6:amd64.postinst
# Found executable: /var/lib/dpkg/info/passwd.postrm
# Found executable: /var/lib/dpkg/info/e2fsprogs.postinst
# Found executable: /var/lib/dpkg/info/debianutils.postrm
# Found executable: /var/lib/dpkg/info/coreutils.postrm
# Found executable: /var/lib/dpkg/info/procps.postrm
# Found executable: /var/lib/dpkg/info/libpam-modules:amd64.postinst
# Found executable: /var/lib/dpkg/info/passwd.postinst
# Found executable: /var/lib/dpkg/info/base-files.prerm
# Found executable: /var/lib/dpkg/info/coreutils.postinst
# Found executable: /var/lib/dpkg/info/util-linux.preinst
# Found executable: /var/lib/dpkg/info/libpam-runtime.postrm
# Found executable: /var/lib/dpkg/info/mawk.prerm
# Found executable: /var/lib/dpkg/info/perl-base.prerm
# Found executable: /var/lib/dpkg/info/bash.preinst
# Found executable: /var/lib/dpkg/info/libpam-runtime.postinst
# Found executable: /var/lib/dpkg/info/libpam-modules:amd64.preinst
# Found executable: /var/lib/dpkg/info/apt.prerm
# Found executable: /var/lib/dpkg/info/lsb-base.prerm
# Found executable: /var/lib/dpkg/info/perl-base.postinst
# Found executable: /var/lib/dpkg/info/lsb-base.preinst
# Found executable: /var/lib/dpkg/info/debconf.config
# Found executable: /var/lib/dpkg/info/debconf.postrm
# Found executable: /var/lib/dpkg/info/lsb-base.postinst
# Found executable: /var/lib/dpkg/info/e2fsprogs.preinst
# Found executable: /var/lib/dpkg/info/base-files.preinst
# Found executable: /var/lib/dpkg/info/procps.prerm
# Found executable: /var/lib/dpkg/info/debconf.postinst
# Found executable: /var/lib/dpkg/info/adduser.config
# Found executable: /var/lib/dpkg/info/bash.postinst
# Found executable: /var/lib/dpkg/info/libpam0g:amd64.postrm
# Found executable: /var/lib/dpkg/info/libpam-modules:amd64.postrm
# Found executable: /var/lib/dpkg/info/bash.postrm
# Found executable: /var/lib/dpkg/info/procps.postinst
# Found executable: /var/lib/dpkg/info/base-passwd.postinst
# Found executable: /var/lib/dpkg/info/dpkg.postrm
# Found executable: /var/lib/dpkg/info/passwd.preinst
# Found executable: /var/lib/dpkg/info/apt.postinst
# Found executable: /var/lib/dpkg/info/perl-base.preinst
# Found executable: /var/lib/dpkg/info/debconf.prerm
# Found executable: /var/lib/dpkg/info/tar.postinst
# Found executable: /var/lib/dpkg/info/base-files.postinst
# Found executable: /var/lib/dpkg/info/libc6:amd64.postrm
# Found executable: /var/lib/dpkg/info/libc-bin.postinst
# Found executable: /var/lib/dpkg/info/base-files.postrm
# Found executable: /var/lib/dpkg/info/e2fsprogs.postrm
# Found executable: /var/lib/dpkg/info/e2fsprogs.prerm
# Found executable: /var/lib/dpkg/info/libstdc++6:amd64.prerm
# Found executable: /var/lib/dpkg/info/lsb-base.postrm
# Found executable: /var/lib/dpkg/info/perl-base.postrm
# Found executable: /var/lib/dpkg/info/moby-engine.postinst
# Found executable: /var/lib/dpkg/info/iptables.postinst
# Found executable: /var/lib/dpkg/info/moby-engine.postrm
# Found executable: /var/lib/dpkg/info/moby-containerd.prerm
# Found executable: /var/lib/dpkg/info/moby-containerd.postinst
# Found executable: /var/lib/dpkg/info/pigz.prerm
# Found executable: /var/lib/dpkg/info/moby-containerd.postrm
# Found executable: /var/lib/dpkg/info/moby-cli.postinst
# Found executable: /var/lib/dpkg/info/iptables.prerm
# Found executable: /var/lib/dpkg/info/moby-engine.prerm
# Found executable: /var/lib/dpkg/info/netbase.postinst
# Found executable: /var/lib/dpkg/info/netbase.postrm
# Found executable: /var/lib/dpkg/info/git-lfs.postinst
# Found executable: /var/lib/dpkg/info/git-lfs.prerm
# Found executable: /var/lib/dpkg/info/libwrap0:amd64.postinst
# Found executable: /var/lib/dpkg/info/libwrap0:amd64.postrm
# Found executable: /var/lib/dpkg/info/openssh-server.preinst
# Found executable: /var/lib/dpkg/info/openssh-server.prerm
# Found executable: /var/lib/dpkg/info/openssh-server.postrm
# Found executable: /var/lib/dpkg/info/openssh-server.config
# Found executable: /var/lib/dpkg/info/openssh-server.postinst
# Found executable: /var/lib/dpkg/info/gawk.postinst
# Found executable: /var/lib/dpkg/info/bison.preinst
# Found executable: /var/lib/dpkg/info/bison.postinst
# Found executable: /var/lib/dpkg/info/bison.prerm
# Found executable: /var/lib/dpkg/info/gawk.prerm
# Found executable: /var/lib/dpkg/info/vim-tiny.postinst
# Found executable: /var/lib/dpkg/info/bash-completion.preinst
# Found executable: /var/lib/dpkg/info/zsh-common.prerm
# Found executable: /var/lib/dpkg/info/iproute2.postrm
# Found executable: /var/lib/dpkg/info/less.prerm
# Found executable: /var/lib/dpkg/info/psmisc.postrm
# Found executable: /var/lib/dpkg/info/dirmngr.prerm
# Found executable: /var/lib/dpkg/info/psmisc.postinst
# Found executable: /var/lib/dpkg/info/git.postinst
# Found executable: /var/lib/dpkg/info/pinentry-curses.postinst
# Found executable: /var/lib/dpkg/info/zsh.preinst
# Found executable: /var/lib/dpkg/info/pinentry-curses.prerm
# Found executable: /var/lib/dpkg/info/zsh-common.postrm
# Found executable: /var/lib/dpkg/info/zsh.postinst
# Found executable: /var/lib/dpkg/info/zsh.postrm
# Found executable: /var/lib/dpkg/info/dirmngr.preinst
# Found executable: /var/lib/dpkg/info/bash-completion.prerm
# Found executable: /var/lib/dpkg/info/locales.postinst
# Found executable: /var/lib/dpkg/info/vim-tiny.preinst
# Found executable: /var/lib/dpkg/info/dirmngr.postinst
# Found executable: /var/lib/dpkg/info/zsh-common.preinst
# Found executable: /var/lib/dpkg/info/zsh.prerm
# Found executable: /var/lib/dpkg/info/nano.postinst
# Found executable: /var/lib/dpkg/info/git.preinst
# Found executable: /var/lib/dpkg/info/locales.config
# Found executable: /var/lib/dpkg/info/bash-completion.postinst
# Found executable: /var/lib/dpkg/info/gpg-agent.postrm
# Found executable: /var/lib/dpkg/info/less.postinst
# Found executable: /var/lib/dpkg/info/openssh-client.postinst
# Found executable: /var/lib/dpkg/info/gpg-agent.postinst
# Found executable: /var/lib/dpkg/info/git.postrm
# Found executable: /var/lib/dpkg/info/openssh-client.preinst
# Found executable: /var/lib/dpkg/info/zsh-common.postinst
# Found executable: /var/lib/dpkg/info/sudo.postinst
# Found executable: /var/lib/dpkg/info/iproute2.config
# Found executable: /var/lib/dpkg/info/sudo.preinst
# Found executable: /var/lib/dpkg/info/iproute2.postinst
# Found executable: /var/lib/dpkg/info/git.prerm
# Found executable: /var/lib/dpkg/info/openssh-client.prerm
# Found executable: /var/lib/dpkg/info/sudo.postrm
# Found executable: /var/lib/dpkg/info/less.preinst
# Found executable: /var/lib/dpkg/info/openssh-client.postrm
# Found executable: /var/lib/dpkg/info/vim-tiny.postrm
# Found executable: /var/lib/dpkg/info/sudo.prerm
# Found executable: /var/lib/dpkg/info/locales.prerm
# Found executable: /var/lib/dpkg/info/nano.prerm
# Found executable: /var/lib/dpkg/info/bash-completion.postrm
# Found executable: /var/lib/dpkg/info/locales.postrm
# Found executable: /var/lib/dpkg/info/dirmngr.postrm
# Found executable: /var/lib/dpkg/info/vim-tiny.prerm
# Found executable: /var/lib/dpkg/info/lynx.postrm
# Found executable: /var/lib/dpkg/info/man-db.prerm
# Found executable: /var/lib/dpkg/info/bc.postinst
# Found executable: /var/lib/dpkg/info/javascript-common.postrm
# Found executable: /var/lib/dpkg/info/man-db.preinst
# Found executable: /var/lib/dpkg/info/lynx.prerm
# Found executable: /var/lib/dpkg/info/javascript-common.prerm
# Found executable: /var/lib/dpkg/info/javascript-common.preinst
# Found executable: /var/lib/dpkg/info/man-db.postinst
# Found executable: /var/lib/dpkg/info/lynx.postinst
# Found executable: /var/lib/dpkg/info/javascript-common.postinst
# Found executable: /var/lib/dpkg/info/fish.postinst
# Found executable: /var/lib/dpkg/info/fish.postrm
# Found executable: /var/lib/dpkg/info/man-db.postrm
# Found executable: /var/lib/dpkg/info/man-db.config
# Found executable: /var/lib/dpkg/info/bsdmainutils.prerm
# Found executable: /var/lib/dpkg/info/bsdmainutils.postinst
# Found executable: /var/lib/dpkg/info/fish.preinst
# Found executable: /var/lib/dpkg/info/bc.postrm
# Found executable: /var/lib/dpkg/info/fish.prerm
# Found executable: /var/lib/dpkg/info/vim-common.postinst
# Found executable: /var/lib/dpkg/info/hicolor-icon-theme.postinst
# Found executable: /var/lib/dpkg/info/libc6-i386.postrm
# Found executable: /var/lib/dpkg/info/vim-common.prerm
# Found executable: /var/lib/dpkg/info/binfmt-support.prerm
# Found executable: /var/lib/dpkg/info/cmake-data.postinst
# Found executable: /var/lib/dpkg/info/vim-common.preinst
# Found executable: /var/lib/dpkg/info/libblkid-dev:amd64.postrm
# Found executable: /var/lib/dpkg/info/adwaita-icon-theme.postinst
# Found executable: /var/lib/dpkg/info/cmake-data.preinst
# Found executable: /var/lib/dpkg/info/llvm.preinst
# Found executable: /var/lib/dpkg/info/shared-mime-info.postinst
# Found executable: /var/lib/dpkg/info/clang.postinst
# Found executable: /var/lib/dpkg/info/python3-pygments.prerm
# Found executable: /var/lib/dpkg/info/shared-mime-info.postrm
# Found executable: /var/lib/dpkg/info/cmake-data.prerm
# Found executable: /var/lib/dpkg/info/libblkid-dev:amd64.prerm
# Found executable: /var/lib/dpkg/info/gtk-update-icon-cache.preinst
# Found executable: /var/lib/dpkg/info/binfmt-support.postinst
# Found executable: /var/lib/dpkg/info/vim.prerm
# Found executable: /var/lib/dpkg/info/vim-runtime.postrm
# Found executable: /var/lib/dpkg/info/clang.prerm
# Found executable: /var/lib/dpkg/info/libglib2.0-dev-bin.postinst
# Found executable: /var/lib/dpkg/info/llvm-10-runtime.postinst
# Found executable: /var/lib/dpkg/info/ubuntu-mono.postinst
# Found executable: /var/lib/dpkg/info/libglib2.0-dev:amd64.prerm
# Found executable: /var/lib/dpkg/info/binfmt-support.preinst
# Found executable: /var/lib/dpkg/info/libblkid-dev:amd64.preinst
# Found executable: /var/lib/dpkg/info/valgrind.postrm
# Found executable: /var/lib/dpkg/info/python3-yaml.prerm
# Found executable: /var/lib/dpkg/info/librsvg2-common:amd64.postinst
# Found executable: /var/lib/dpkg/info/gdb.postinst
# Found executable: /var/lib/dpkg/info/fontconfig.postinst
# Found executable: /var/lib/dpkg/info/libgdk-pixbuf2.0-0:amd64.postrm
# Found executable: /var/lib/dpkg/info/python3-yaml.postinst
# Found executable: /var/lib/dpkg/info/binfmt-support.postrm
# Found executable: /var/lib/dpkg/info/lib32stdc++6.postinst
# Found executable: /var/lib/dpkg/info/ubuntu-mono.postrm
# Found executable: /var/lib/dpkg/info/valgrind.postinst
# Found executable: /var/lib/dpkg/info/valgrind.prerm
# Found executable: /var/lib/dpkg/info/vim.postinst
# Found executable: /var/lib/dpkg/info/humanity-icon-theme.postinst
# Found executable: /var/lib/dpkg/info/libgdk-pixbuf2.0-0:amd64.postinst
# Found executable: /var/lib/dpkg/info/libglib2.0-dev-bin.prerm
# Found executable: /var/lib/dpkg/info/lldb-10.postinst
# Found executable: /var/lib/dpkg/info/libgtk-3-0:amd64.postinst
# Found executable: /var/lib/dpkg/info/vim.preinst
# Found executable: /var/lib/dpkg/info/humanity-icon-theme.postrm
# Found executable: /var/lib/dpkg/info/vim-runtime.preinst
# Found executable: /var/lib/dpkg/info/vim-runtime.postinst
# Found executable: /var/lib/dpkg/info/adwaita-icon-theme.postrm
# Found executable: /var/lib/dpkg/info/hicolor-icon-theme.prerm
# Found executable: /var/lib/dpkg/info/fontconfig.postrm
# Found executable: /var/lib/dpkg/info/python3-pygments.postinst
# Found executable: /var/lib/dpkg/info/valgrind.preinst
# Found executable: /var/lib/dpkg/info/libblkid-dev:amd64.postinst
# Found executable: /var/lib/dpkg/info/vim-common.postrm
# Found executable: /var/lib/dpkg/info/libgtk-3-0:amd64.postrm
# Found executable: /var/lib/dpkg/info/llvm-10-runtime.prerm
# Found executable: /var/lib/dpkg/info/gdb.postrm
# Found executable: /var/lib/dpkg/info/vim.postrm
# Found executable: /var/lib/dpkg/info/adwaita-icon-theme.prerm
# Found executable: /var/lib/dpkg/info/odbcinst.postrm
# Found executable: /var/lib/dpkg/info/systemd-timesyncd.prerm
# Found executable: /var/lib/dpkg/info/ucf.postinst
# Found executable: /var/lib/dpkg/info/python3-software-properties.postinst
# Found executable: /var/lib/dpkg/info/python3-certifi.postinst
# Found executable: /var/lib/dpkg/info/mysql-common.preinst
# Found executable: /var/lib/dpkg/info/python3-gi.postinst
# Found executable: /var/lib/dpkg/info/python3.8-minimal.postinst
# Found executable: /var/lib/dpkg/info/tcl.preinst
# Found executable: /var/lib/dpkg/info/python3-apt.prerm
# Found executable: /var/lib/dpkg/info/python3-gi.prerm
# Found executable: /var/lib/dpkg/info/fontconfig-config.postrm
# Found executable: /var/lib/dpkg/info/packagekit.prerm
# Found executable: /var/lib/dpkg/info/python3-dbus.postinst
# Found executable: /var/lib/dpkg/info/rsync.postrm
# Found executable: /var/lib/dpkg/info/x11-common.preinst
# Found executable: /var/lib/dpkg/info/libglib2.0-0:amd64.postinst
# Found executable: /var/lib/dpkg/info/libssl1.1:amd64.postrm
# Found executable: /var/lib/dpkg/info/python3-requests.postinst
# Found executable: /var/lib/dpkg/info/pkg-config.prerm
# Found executable: /var/lib/dpkg/info/libfreetype6-dev:amd64.postrm
# Found executable: /var/lib/dpkg/info/systemd.postinst
# Found executable: /var/lib/dpkg/info/packagekit.preinst
# Found executable: /var/lib/dpkg/info/python3-chardet.prerm
# Found executable: /var/lib/dpkg/info/libfreetype6-dev:amd64.prerm
# Found executable: /var/lib/dpkg/info/tzdata.config
# Found executable: /var/lib/dpkg/info/python3-distutils.postinst
# Found executable: /var/lib/dpkg/info/unzip.postinst
# Found executable: /var/lib/dpkg/info/python3-pkg-resources.postinst
# Found executable: /var/lib/dpkg/info/libglib2.0-0:amd64.postrm
# Found executable: /var/lib/dpkg/info/dbus.postinst
# Found executable: /var/lib/dpkg/info/python3-lib2to3.postinst
# Found executable: /var/lib/dpkg/info/x11-common.postinst
# Found executable: /var/lib/dpkg/info/rsync.prerm
# Found executable: /var/lib/dpkg/info/libfreetype6-dev:amd64.postinst
# Found executable: /var/lib/dpkg/info/mysql-common.postinst
# Found executable: /var/lib/dpkg/info/ca-certificates.config
# Found executable: /var/lib/dpkg/info/g++.prerm
# Found executable: /var/lib/dpkg/info/xz-utils.prerm
# Found executable: /var/lib/dpkg/info/python3-pip.prerm
# Found executable: /var/lib/dpkg/info/pkg-config.postinst
# Found executable: /var/lib/dpkg/info/libgssapi-krb5-2:amd64.postinst
# Found executable: /var/lib/dpkg/info/libpam-systemd:amd64.postinst
# Found executable: /var/lib/dpkg/info/python3.preinst
# Found executable: /var/lib/dpkg/info/perl.postrm
# Found executable: /var/lib/dpkg/info/dbus.preinst
# Found executable: /var/lib/dpkg/info/libgdiplus.postinst
# Found executable: /var/lib/dpkg/info/libpython3.8-minimal:amd64.postinst
# Found executable: /var/lib/dpkg/info/systemd-timesyncd.postrm
# Found executable: /var/lib/dpkg/info/perl.postinst
# Found executable: /var/lib/dpkg/info/tcl8.6.prerm
# Found executable: /var/lib/dpkg/info/python3-urllib3.postinst
# Found executable: /var/lib/dpkg/info/python3-software-properties.prerm
# Found executable: /var/lib/dpkg/info/python3-lib2to3.prerm
# Found executable: /var/lib/dpkg/info/libssl1.1:amd64.postinst
# Found executable: /var/lib/dpkg/info/policykit-1.prerm
# Found executable: /var/lib/dpkg/info/gcc.prerm
# Found executable: /var/lib/dpkg/info/libpython3.8-stdlib:amd64.prerm
# Found executable: /var/lib/dpkg/info/x11-common.postrm
# Found executable: /var/lib/dpkg/info/g++.postinst
# Found executable: /var/lib/dpkg/info/mysql-common.postrm
# Found executable: /var/lib/dpkg/info/python3-chardet.postinst
# Found executable: /var/lib/dpkg/info/python3-six.postinst
# Found executable: /var/lib/dpkg/info/python3-pkg-resources.prerm
# Found executable: /var/lib/dpkg/info/libfreetype6-dev:amd64.preinst
# Found executable: /var/lib/dpkg/info/tcl8.6.postinst
# Found executable: /var/lib/dpkg/info/policykit-1.postinst
# Found executable: /var/lib/dpkg/info/tk.preinst
# Found executable: /var/lib/dpkg/info/python3-idna.postinst
# Found executable: /var/lib/dpkg/info/tk8.6.prerm
# Found executable: /var/lib/dpkg/info/tzdata.postrm
# Found executable: /var/lib/dpkg/info/packagekit.postrm
# Found executable: /var/lib/dpkg/info/tk8.6.postrm
# Found executable: /var/lib/dpkg/info/ca-certificates.postrm
# Found executable: /var/lib/dpkg/info/libpython3.8-minimal:amd64.prerm
# Found executable: /var/lib/dpkg/info/tcl8.6.postrm
# Found executable: /var/lib/dpkg/info/x11-common.prerm
# Found executable: /var/lib/dpkg/info/automake.prerm
# Found executable: /var/lib/dpkg/info/software-properties-common.postinst
# Found executable: /var/lib/dpkg/info/mime-support.postinst
# Found executable: /var/lib/dpkg/info/dbus.prerm
# Found executable: /var/lib/dpkg/info/lsb-release.postinst
# Found executable: /var/lib/dpkg/info/libpam-systemd:amd64.prerm
# Found executable: /var/lib/dpkg/info/readline-common.postinst
# Found executable: /var/lib/dpkg/info/python3-wheel.postinst
# Found executable: /var/lib/dpkg/info/openssl.postinst
# Found executable: /var/lib/dpkg/info/cpp.prerm
# Found executable: /var/lib/dpkg/info/python3-minimal.postinst
# Found executable: /var/lib/dpkg/info/python3-dbus.prerm
# Found executable: /var/lib/dpkg/info/python3-setuptools.postinst
# Found executable: /var/lib/dpkg/info/python3-pip.postinst
# Found executable: /var/lib/dpkg/info/automake.postinst
# Found executable: /var/lib/dpkg/info/python3.postinst
# Found executable: /var/lib/dpkg/info/python3-apt.postinst
# Found executable: /var/lib/dpkg/info/python3-setuptools.prerm
# Found executable: /var/lib/dpkg/info/python3.postrm
# Found executable: /var/lib/dpkg/info/python3-six.prerm
# Found executable: /var/lib/dpkg/info/lsb-release.postrm
# Found executable: /var/lib/dpkg/info/policykit-1.preinst
# Found executable: /var/lib/dpkg/info/systemd-timesyncd.postinst
# Found executable: /var/lib/dpkg/info/gcc.postinst
# Found executable: /var/lib/dpkg/info/python3-wheel.prerm
# Found executable: /var/lib/dpkg/info/perl.prerm
# Found executable: /var/lib/dpkg/info/python3.prerm
# Found executable: /var/lib/dpkg/info/systemd.postrm
# Found executable: /var/lib/dpkg/info/python3.8-minimal.postrm
# Found executable: /var/lib/dpkg/info/readline-common.postrm
# Found executable: /var/lib/dpkg/info/ucf.postrm
# Found executable: /var/lib/dpkg/info/cpp.postinst
# Found executable: /var/lib/dpkg/info/python3-idna.prerm
# Found executable: /var/lib/dpkg/info/dbus.postrm
# Found executable: /var/lib/dpkg/info/software-properties-common.prerm
# Found executable: /var/lib/dpkg/info/fontconfig-config.postinst
# Found executable: /var/lib/dpkg/info/automake.preinst
# Found executable: /var/lib/dpkg/info/ca-certificates.postinst
# Found executable: /var/lib/dpkg/info/tk8.6.postinst
# Found executable: /var/lib/dpkg/info/policykit-1.postrm
# Found executable: /var/lib/dpkg/info/rsync.postinst
# Found executable: /var/lib/dpkg/info/systemd-sysv.postinst
# Found executable: /var/lib/dpkg/info/libpython3.8-minimal:amd64.postrm
# Found executable: /var/lib/dpkg/info/systemd.prerm
# Found executable: /var/lib/dpkg/info/python3.8.postinst
# Found executable: /var/lib/dpkg/info/libgssapi-krb5-2:amd64.postrm
# Found executable: /var/lib/dpkg/info/python3-requests.prerm
# Found executable: /var/lib/dpkg/info/ucf.preinst
# Found executable: /var/lib/dpkg/info/mime-support.prerm
# Found executable: /var/lib/dpkg/info/python3.8-minimal.preinst
# Found executable: /var/lib/dpkg/info/python3-certifi.prerm
# Found executable: /var/lib/dpkg/info/python3.8.prerm
# Found executable: /var/lib/dpkg/info/python3-requests-unixsocket.postinst
# Found executable: /var/lib/dpkg/info/packagekit.postinst
# Found executable: /var/lib/dpkg/info/libgstreamer1.0-0:amd64.postinst
# Found executable: /var/lib/dpkg/info/python3-requests-unixsocket.prerm
# Found executable: /var/lib/dpkg/info/mysql-common.prerm
# Found executable: /var/lib/dpkg/info/perl.preinst
# Found executable: /var/lib/dpkg/info/unzip.postrm
# Found executable: /var/lib/dpkg/info/systemd.preinst
# Found executable: /var/lib/dpkg/info/python3-urllib3.prerm
# Found executable: /var/lib/dpkg/info/python3.8-minimal.prerm
# Found executable: /var/lib/dpkg/info/xz-utils.postinst
# Found executable: /var/lib/dpkg/info/tzdata.postinst
# Found executable: /var/lib/dpkg/info/python3-distutils.prerm
# Found executable: /var/lib/dpkg/info/python3-minimal.prerm
# Found executable: /proc/1/exe
# Found executable: /proc/1/task/1/exe
# Found executable: /proc/7/exe
# Found executable: /proc/7/task/7/exe
# Found executable: /proc/193/exe
# Found executable: /proc/193/task/193/exe
# Found executable: /proc/526/exe
# Found executable: /proc/526/task/526/exe
# Found executable: /proc/526/task/526/fd/10
# Found executable: /proc/526/fd/10
# Found executable: /proc/535/exe
# Found executable: /proc/535/task/535/exe
# Found executable: /proc/535/task/535/fd/18
# Found executable: /proc/535/task/535/fd/21
# Found executable: /proc/535/task/535/fd/22
# Found executable: /proc/535/task/535/fd/23
# Found executable: /proc/535/task/535/fd/24
# Found executable: /proc/535/task/535/fd/25
# Found executable: /proc/535/task/535/fd/29
# Found executable: /proc/535/task/535/fd/32
# Found executable: /proc/535/task/535/fd/34
# Found executable: /proc/52102/task/52102/fd/23
# Found executable: /proc/52102/task/52102/fd/33
# Found executable: /proc/52102/task/52102/fd/34
# Found executable: /proc/52102/task/52102/fd/36
# Found executable: /proc/52102/task/52102/fd/47
# Found executable: /proc/52102/task/52102/fd/51
# Found executable: /proc/52102/task/52102/fd/54
# Found executable: /proc/52102/task/52102/fd/56
# Found executable: /proc/52102/task/52102/fd/57
# Found executable: /proc/52102/task/52102/fd/62
# Found executable: /proc/52102/task/52102/fd/63
# Found executable: /proc/52102/task/52102/fd/64
# Found executable: /proc/52102/task/52102/fd/65
# Found executable: /proc/52102/task/52128/exe
# Found executable: /proc/52102/task/52128/fd/0
# Found executable: /proc/52102/task/52128/fd/9
# ...
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Common.Timeline.EventLog.Writer.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Base.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.dotTrace.Ide.Core.UnitTesting.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.dotMemory.Assembler.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Skia.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Platform.UIInteractive.Avalonia.Ide.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Themes.Fluent.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.dotTrace.Ide.Core.UnitTesting.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.DotMemory.Ide.Core.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.dotMemory.Shell.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Platform.UIInteractive.Avalonia.Shell.JetMetadata.sstg
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Layout.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Styling.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.X11.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Profiler.Home.GUI.Avalonia.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Visuals.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Common.Timeline.EventLog.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Markup.Xaml.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Common.ExternalStorage.x86.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Controls.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Common.Timeline.EventLog.Interface.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Animation.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Profiler.Configurations.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.DotTrace.DataStructures.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Markup.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/SkiaSharp.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.DotTrace.Features.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.DotTrace.Dal.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/HarfBuzzSharp.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Win32.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/GoogleAnalyticsTracker.Simple.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.OpenGL.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Visuals.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Remote.Protocol.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Profilers.Rider.runtimeconfig.json
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.dotTrace.Ide.Rider.dotTrace.JetMetadata.sstg
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Profilers.Rider.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Themes.Default.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Common.Timeline.EventLog.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Profiler.Home.GUI.Avalonia.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Common.RealtimeChart.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Native.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.Platform.UIInteractive.Shell.Common.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.Diagnostics.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/Avalonia.MicroCom.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/JetBrains.dotMemory.Home.GUI.Avalonia.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/macos-arm64/JetBrains.Profilers.Rider
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/windows-arm64/JetBrains.Profilers.Rider.exe
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/windows-x64/JetBrains.Profilers.Rider.exe
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/linux-arm64/JetBrains.Profilers.Rider
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/GoogleAnalyticsTracker.Core.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/Microsoft.FileFormats.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/GoogleAnalyticsTracker.Simple.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/DynamicData.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/HtmlAgilityPack.xml
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/AutoMapper.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/GoogleAnalyticsTracker.Core.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/HtmlAgilityPack.deps.json
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/protobuf-net.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/Microsoft.SymbolStore.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/HtmlAgilityPack.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/HtmlAgilityPack.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/System.Runtime.InteropServices.WindowsRuntime.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/NetCore/GoogleAnalyticsTracker.Simple.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/macos-x64/JetBrains.Profilers.Rider
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/linux-x64/libHarfBuzzSharp.so
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/linux-x64/libSkiaSharp.so
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/dotTrace/DotFiles/linux-x64/JetBrains.Profilers.Rider
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/tslint/lib/tslint.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/tslint/js/utils.js
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/tslint/js/convert-tslint-config.js
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/tslint/js/languageService/tslint-plugin.js
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/tslint/js/languageService/tslint-plugin-provider.js
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/qodana/lib/qodana.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/clouds-docker-impl/lib/clouds-docker-impl.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/ini/lib/ini.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/UnrealLink/dotnet/RiderPlugin.UnrealLink.dll
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/UnrealLink/dotnet/RiderPlugin.UnrealLink.pdb
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/UnrealLink/lib/instrumented-UnrealLink-2023.1.0.120.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/UnrealLink/lib/searchableOptions-2023.1.0.120.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/UnrealLink/EditorPlugin/RiderLink.zip
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/w3validators/lib/w3validators.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/properties/lib/properties.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/rider-theme-pack/lib/rider-theme-pack.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/jade/lib/jade.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/nodeJS-remoteInterpreter/lib/nodeJS-remoteInterpreter.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/sh/lib/sh.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/rider-publish-custom-server/lib/rider-publish-custom-server.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/keymap-visualStudio/lib/keymap-visualStudio.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/rider-razor/lib/rider-razor.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/vcs-git/lib/git4idea-rt.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/vcs-git/lib/vcs-git.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/plugins/settingsRepository/lib/settingsRepository.jar
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/license/saxon-conditions.html
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/license/javolution_license.txt
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/license/third-party-libraries.json
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/license/third-party-libraries.html
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/license/yourkit-license-redist.txt
# Found executable: /workspaces/.codespaces/shared/editors/jetbrains/JetBrainsRider-2023.1/license/javahelp_license.txt
# Found executable: /workspaces/PythonbatchNovDec2024/01_Introduction/b_hello_world.py
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/sendemail-validate.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/post-update.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/pre-push.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/update.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/pre-receive.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/pre-rebase.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/push-to-checkout.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/applypatch-msg.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/commit-msg.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/pre-commit.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/prepare-commit-msg.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/pre-applypatch.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/fsmonitor-watchman.sample
# Found executable: /workspaces/PythonbatchNovDec2024/.git/hooks/pre-merge-commit.sample
# Found executable: /go/bin/golint
# Found executable: /go/bin/dlv
# Found executable: /go/bin/gotests
# Found executable: /go/bin/revive
# Found executable: /go/bin/staticcheck
# Found executable: /go/bin/golangci-lint
# Found executable: /go/bin/impl
# Found executable: /go/bin/gopls
# Found executable: /go/bin/gomodifytags
# Found executable: /go/bin/goplay
#
# Total number of executables found: 35348

# %% [markdown]
# Working with paths

# %%
os.path.basename("/home/user/temp.txt")
# Out:
# 'temp.txt'

# %%
os.path.dirname("/home/user/temp.txt")
# Out:
# '/home/user'

# %%
os.path.abspath("temp.txt")
# Out:
# '/workspaces/PythonbatchNovDec2024/12_Modules/04_Os_Module/temp.txt'

# %%
os.getcwd()
# Out:
# '/workspaces/PythonbatchNovDec2024/12_Modules/04_Os_Module'

# %%
assert os.path.abspath("temp.txt") == os.getcwd() + os.sep + "temp.txt"

os.getcwd() + os.sep + "temp.txt"
# Out:
# '/workspaces/PythonbatchNovDec2024/12_Modules/04_Os_Module/temp.txt'

# %%
os.path.realpath("/home/user/temp.txt")
# Out:
# '/home/user/temp.txt'

# %%
os.path.splitext("/home/user/temp.log")
# Out:
# ('/home/user/temp', '.log')

# %%
os.path.splitext("temp.log")
# Out:
# ('temp', '.log')

# %%
os.path.splitdrive("/home/user/temp.txt")
# Out:
# ('', '/home/user/temp.txt')

# %%
os.path.splitdrive("C:/home/user/temp.txt")
# Out:
# ('', 'C:/home/user/temp.txt')

# %%
os.path.extsep
# Out:
# '.'

# %%
import sys

if sys.platform == "win3":
    path_joiner = "\\"
else:
    path_joiner = "/"

print(path_joiner, os.sep)
assert path_joiner == os.sep
# Out:
# / /

# %%
os.path.join("css", "america")
# Out:
# 'css/america'

# %%
os.path.join("css", "america", "asdas", "sad", "dfgd")
# Out:
# 'css/america/asdas/sad/dfgd'

# %%
"\\".join(("css", "america", "asdas", "sad", "dfgd"))
# Out:
# 'css\\america\\asdas\\sad\\dfgd'

# %%
(os.sep).join(("css", "america", "asdas", "sad", "dfgd"))
# Out:
# 'css/america/asdas/sad/dfgd'

# %%
assert os.path.join("css", "america", "asdas", "sad", "dfgd") == (os.sep).join(
    ("css", "america", "asdas", "sad", "dfgd")
)

# %%
new_path = os.path.join("css", "america", "asdas", "sad", "dfgd")
new_path
# Out:
# 'css/america/asdas/sad/dfgd'

# %%
os.path.exists(new_path)
# Out:
# False

# %%
os.makedirs(new_path, exist_ok=False)

# %%
os.system('tree')
# Out:
# .
# ├── a_os_module.ipynb
# └── css
#     └── america
#         └── asdas
#             └── sad
#                 └── dfgd
#
# 5 directories, 1 file
# 0

# %%
os.path.getsize('css')
# Out:
# 4096

# %%
os.path.getctime('css')
# Out:
# 1736229064.5595937

# %%
os.stat('css')
# Out:
# os.stat_result(st_mode=16895, st_ino=1835619, st_dev=1797, st_nlink=3, st_uid=1000, st_gid=1000, st_size=4096, st_atime=1736229067, st_mtime=1736229064, st_ctime=1736229064)

# %%
os.stat('css').st_ctime
# Out:
# 1736229064.5595937

# %% [markdown]
# Attributes which work only on Linux

# %%
# os.getloadavg(): This function returns the system load average over the last 1, 5, and 15 minutes as a tuple.
#  This function is not available on Windows.

os.getloadavg()
# Out:
# (1.13, 0.73, 0.47)

# %%
# os.statvfs(): This function returns information about a file system such as the total size, free space, and file system block size. This function is not available on Windows.

os.statvfs('css')
# Out:
# os.statvfs_result(f_bsize=4096, f_frsize=4096, f_blocks=8211920, f_bfree=5454432, f_bavail=5030908, f_files=2097152, f_ffree=1797490, f_favail=1797490, f_flag=4100, f_namemax=255)
