# %% [markdown]
# Shelve
#
# stores in .db files

# %%
import shelve

# %%
dir(shelve)
# Out:
# ['BsdDbShelf',
#  'BytesIO',
#  'DEFAULT_PROTOCOL',
#  'DbfilenameShelf',
#  'Pickler',
#  'Shelf',
#  'Unpickler',
#  '_ClosedDict',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'collections',
#  'open']

# %%
s = shelve.open("myshelve.db")

s["key1"] = {"int": 10, "float": 9.5, "string": "Sample data"}

s["persondetails"] = person_details ={
    "name": "Tom Brady", 
    "age": 45,
    "location": 'USA'
}

s.close()

# %%
! ls -ltr
# Out:
# total 60
# -rw-rw-rw- 1 codespace codespace    38 Jan  8 05:19 data.pickle
# -rw-rw-rw- 1 codespace codespace    66 Jan  8 05:20 data.pickle.gz
# -rw-rw-rw- 1 codespace codespace    60 Jan  8 05:23 person_details.pkl
# -rw-rw-rw- 1 codespace codespace 27713 Jan  8 05:24 a_pickle.ipynb
# -rw-rw-rw- 1 codespace codespace 16384 Jan  8 05:27 myshelve.db
# -rw-rw-rw- 1 codespace codespace  2066 Jan  8 05:27 b_shelve.ipynb

# %%
! cat myshelve.db
# Out:
# <��������������������������������������������������������������������������������������������������������������������������������������������������������������������f��Gkey10@��������������������������������������������������������������������������������������������������������������������key1��5}�(�int�K                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                s�0��������������������������������������������������������������������������������������������������������������������������������������������������������������������������������
# ...
